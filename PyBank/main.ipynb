# %%
# Import the pathlib and csv library

from pathlib import Path
import csv

# Set the file path

csvpath = Path("C:/Users/navpr/budget_data.csv")

# Initialize dictionary

total_pnl = []
monthly_change = []

# Open the csv file as an object
with open(csvpath, "r") as csvfile:

    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csvreader = csv.reader(csvfile, delimiter=",")

    csv_header = next(csvreader)
    last_month = int(first_row[1])
    
    # Iterate over each element of csvreader    

    for row in csvreader:
        
        change = int(row[1]) - last_month
        last_month = int(row[1])
        monthly_change.append(change)   
        
        pnl = int(row[1])
        total_pnl.append(pnl)
    
    # Initial metric variables

    count = 0
    total = 0
    grand_total = 0
    minimum = 0
    maximum = 0
 
    # Iterate over each element of total_pnl

    for total_sum in total_pnl:
        
        grand_total += total_sum
    
    # Iterate over each element of monthly_change
    
    for changes in monthly_change:

        count += 1
        
        # Logic to find the min and max values

        if minimum == 0:
            minimum = changes
        elif changes < minimum:
            minimum = changes
        elif changes > maximum:
            maximum = changes
            
# Calculate average change
            
average_change = round(sum(monthly_change) / (len(monthly_change) - 1), 2)
            
# Print resulting analysis

print ("Financial Analysis")
print ("----------------------------")
print (f"Total Months: {count}")
print (f"Total: ${grand_total}")
print (f"Average Change: ${average_change}")
print (f"Greatest Increase in Profits: ${maximum}")
print (f"Greatest Decrease in Profits: ${minimum}")

### Generate Analysis as Text File

# Set the path for analysis.txt
analysis_path = Path("Analysis.txt")

lines = ["Financial Analysis", "----------------------------", f"Total Months: {count}", f"Total: ${grand_total}", f"Average Change: ${average_change}", f"Greatest Increase in Profits: ${maximum}", f"Greatest Decrease in Profits: ${minimum}"]
with open('analysis.txt', 'w') as f:
    f.write('\n'.join(lines))
# Out:
# Financial Analysis
# ----------------------------
# Total Months: 86
# Total: $38382578
# Average Change: $-2315.12
# Greatest Increase in Profits: $1926159
# Greatest Decrease in Profits: $-2196167
